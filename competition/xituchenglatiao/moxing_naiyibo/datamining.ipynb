# %%
import numpy as np
import pandas as pd


train = pd.read_csv('./data/months1_10/dev/10.csv')

# %%
data = train.groupby(['phone_id'],as_index = False).count()

# %%
train[train['phone_id'] == 2]
# Out:
#          phone_id     time_stamp  loc_id
# 5747777         2  2017-10-16 09      12

# %%
data.to_csv('gg.csv',index=False)

# %%
data
# Out:
#          phone_id  time_stamp  loc_id
# 0               2           1       1
# 1               3           1       1
# 2               8           2       2
# 3              30           1       1
# 4              40           1       1
# 5              42           2       2
# 6              55           2       2
# 7              62           1       1
# 8              74           2       2
# 9              75           1       1
# 10             80           1       1
# 11             82           1       1
# 12             93           2       2
# 13            104           2       2
# 14            118           1       1
# 15            121           2       2
# 16            123           1       1
# 17            136           1       1
# 18            137           2       2
# 19            153           2       2
# 20            161           1       1
# 21            172           2       2
# 22            173           2       2
# 23            182          14      14
# ...
